# %% [markdown]
# ### dataset preprocessing

# %%
import pandas as pd
import os
import glob
import torch
import numpy as np
import re
from pointnet2_ops import pointnet2_utils  # FPS 사용

def _extract_tree_id_from_filename(csv_path: str) -> int:
    """파일명에서 8자리 숫자를 찾아 앞 4자리를 tree_id로 반환 (정수 나눗셈 // 10000)."""
    stem = os.path.splitext(os.path.basename(csv_path))[0]  # 예: '06620000'
    m = re.search(r'(\d{8})', stem)
    if not m:
        # 8자리가 아니면, 파일명 내 숫자만 모아 처리(안전장치)
        digits = ''.join(ch for ch in stem if ch.isdigit())
        if len(digits) >= 8:
            base = int(digits[-8:])
        else:
            raise ValueError(f"파일명에서 8자리 숫자를 찾을 수 없음: {csv_path}")
    else:
        base = int(m.group(1))
    return base // 10000  # 앞 4자리

def voxelize_and_downsample(input_dir, output_dir, voxel_size=1,
                            max_points_per_voxel=32768, start_index=1):
    os.makedirs(output_dir, exist_ok=True)
    csv_files = sorted(glob.glob(os.path.join(input_dir, "*.csv")))
    print(f"Found {len(csv_files)} CSV files in {input_dir}.")
    csv_files = csv_files[start_index-1:]  # 1-based

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    for csv_idx, csv_file in enumerate(csv_files, start=start_index):
        print(f"\nProcessing {csv_idx}: {csv_file}")

        # 파일명에서 tree_id 추출 (06620000 -> 0662 -> 662)
        try:
            tree_id = _extract_tree_id_from_filename(csv_file)
        except Exception as e:
            print(f"[SKIP] tree_id 추출 실패: {csv_file} :: {e}")
            continue

        # ---- CSV 읽기(헤더 없음, 자동 구분자) ----
        try:
            df = pd.read_csv(csv_file, header=None, sep=None, engine="python")
        except Exception as e:
            print(f"[SKIP] read_csv 실패: {csv_file} :: {e}")
            continue

        if df.shape[1] < 3:
            print(f"[SKIP] {csv_file}: 열이 3개 미만입니다({df.shape[1]}개).")
            continue

        # 3컬럼 또는 4+컬럼 정규화 → (x,y,z,type)
        if df.shape[1] == 3:
            df.columns = ['x', 'y', 'z']
            df['type'] = -1
        else:
            df = df.iloc[:, :4]
            df.columns = ['x', 'y', 'z', 'type']

        df[['x','y','z']] = df[['x','y','z']].astype(np.float32)
        try:
            df['type'] = df['type'].astype(np.int32)
        except Exception:
            df['type'] = -1

        # ---- Voxelization ----
        df['voxel_x'] = np.floor(df['x'] / voxel_size).astype(np.int64)
        df['voxel_y'] = np.floor(df['y'] / voxel_size).astype(np.int64)
        df['voxel_z'] = np.floor(df['z'] / voxel_size).astype(np.int64)

        # voxel_id 부여 (파일 내에서 1..K)
        voxel_keys = df[['voxel_x','voxel_y','voxel_z']].drop_duplicates().values.tolist()
        voxel_keys = sorted(voxel_keys)
        voxel_to_index = {tuple(key): idx+1 for idx, key in enumerate(voxel_keys)}
        df['voxel_id'] = df[['voxel_x','voxel_y','voxel_z']].apply(tuple, axis=1).map(voxel_to_index)

        grouped = df.groupby('voxel_id', sort=True)
        voxel_point_counts = grouped.size()
        print(f"File {csv_idx}: Max points in a voxel = {voxel_point_counts.max()}")
        print(f"File {csv_idx}: Min points in a voxel = {voxel_point_counts.min()}")

        # ---- 복셀별 저장 ----
        for voxel_id, group in grouped:
            # 최종 번호: i*10000 + voxel_id  → 8자리 zero-pad
            i_val = int(tree_id) * 10000 + int(voxel_id)
            i_str = f"{i_val:08d}"  # 예: 6620001 -> '006620001'이 아니라 '006620001'? (주의: 8자리 유지)
            # 위에서 8자리 보장을 위해 tree_id(0~9999), voxel_id(1~9999) 가정
            file_name = f"99999999-{i_str}.csv"
            file_path = os.path.join(output_dir, file_name)

            grp = group.reset_index(drop=True)
            n = len(grp)
            if n > max_points_per_voxel:
                pts = torch.from_numpy(grp[['x','y','z']].to_numpy(np.float32)).unsqueeze(0).to(device).contiguous()
                try:
                    idx = pointnet2_utils.furthest_point_sample(pts, max_points_per_voxel)  # (1,M)
                    sel = idx.squeeze(0).long().cpu().numpy()
                    sampled = grp.iloc[sel]
                except Exception as e:
                    print(f"[WARN] FPS 실패(원본 저장): voxel_id={voxel_id}, N={n} :: {e}")
                    sampled = grp
            else:
                sampled = grp

            sampled[['x','y','z','type']].to_csv(file_path, index=False, header=False)

    print("\n[Done] Voxelization + (optional) FPS downsampling finished.")


# 실행 예시
input_dir = "/esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222"
output_dir = "/esail4/heeju/REGRESSION/Point-M2AE/data/06masked_voxel/22222222"

voxelize_and_downsample(input_dir, output_dir, start_index=1)
# Out:
# Found 12 CSV files in /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222.
#
# Processing 1: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/06620000.csv
# File 1: Max points in a voxel = 284204
# File 1: Min points in a voxel = 2528
#
# Processing 2: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/06630000.csv
# File 2: Max points in a voxel = 1154385
# File 2: Min points in a voxel = 404
#
# Processing 3: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/06640000.csv
# File 3: Max points in a voxel = 729145
# File 3: Min points in a voxel = 45
#
# Processing 4: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/07670000.csv
# File 4: Max points in a voxel = 35969
# File 4: Min points in a voxel = 276
#
# Processing 5: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/08620000.csv
# File 5: Max points in a voxel = 36482
# File 5: Min points in a voxel = 238
#
# Processing 6: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/15320000.csv
# File 6: Max points in a voxel = 76011
# File 6: Min points in a voxel = 1015
#
# Processing 7: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/16270000.csv
# File 7: Max points in a voxel = 90231
# File 7: Min points in a voxel = 11
#
# Processing 8: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/17270000.csv
# File 8: Max points in a voxel = 81132
# File 8: Min points in a voxel = 95
#
# Processing 9: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/18240000.csv
# File 9: Max points in a voxel = 78935
# File 9: Min points in a voxel = 283
#
# Processing 10: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/19180000.csv
# File 10: Max points in a voxel = 127170
# File 10: Min points in a voxel = 109
#
# Processing 11: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/23880000.csv
# File 11: Max points in a voxel = 26502
# File 11: Min points in a voxel = 125
#
# Processing 12: /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/22222222/24000000.csv
# File 12: Max points in a voxel = 23881
# File 12: Min points in a voxel = 34
#
# [Done] Voxelization + (optional) FPS downsampling finished.

# %%
import os
import pandas as pd

# 경로 설정
target_dir = '/esail4/heeju/REGRESSION/Point-M2AE/data/06masked_voxel/33333333'

# 해당 디렉토리의 모든 csv 파일 찾기
csv_files = [f for f in os.listdir(target_dir) if f.endswith('.csv')]

# 기준 이하 파일 삭제
for file in csv_files:
    file_path = os.path.join(target_dir, file)
    try:
        df = pd.read_csv(file_path)
        if len(df) <= 50:
            os.remove(file_path)
            print(f'Deleted: {file}')
    except Exception as e:
        print(f'Error reading {file}: {e}')
# Out:
# Deleted: 99999999-15430044.csv
# Deleted: 99999999-15710050.csv
# Deleted: 99999999-15710065.csv
# Deleted: 99999999-22360015.csv
# Deleted: 99999999-22360016.csv
# Deleted: 99999999-22360037.csv
# Deleted: 99999999-22360038.csv
# Deleted: 99999999-22360039.csv
# Deleted: 99999999-22360040.csv
# Deleted: 99999999-22360042.csv

# %%
import os
import shutil

# 입력 및 출력 디렉토리 경로 설정
src_dir = '/esail4/heeju/REGRESSION/Point-M2AE/data/06masked_voxel/33333333'
dst_dir = '/esail4/heeju/REGRESSION/Point-M2AE/data/06masked_inf/33333333'

# 출력 디렉토리가 없으면 생성
os.makedirs(dst_dir, exist_ok=True)

# 소스 디렉토리 내 파일 순회
for filename in os.listdir(src_dir):
    if filename.endswith('.csv') and filename.startswith('99999999-'):
        # 숫자 ID 추출
        numeric_id = filename.split('-')[1].replace('.csv', '')
        
        # 복사 대상 경로
        new_filename = f'{numeric_id}.csv'
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_dir, new_filename)
        
        # 파일 복사
        shutil.copyfile(src_path, dst_path)
        print(f'Copied: {filename} → {new_filename}')
# Out:
# Copied: 99999999-05530001.csv → 05530001.csv
# Copied: 99999999-05530002.csv → 05530002.csv
# Copied: 99999999-05530003.csv → 05530003.csv
# Copied: 99999999-05530004.csv → 05530004.csv
# Copied: 99999999-05530005.csv → 05530005.csv
# Copied: 99999999-05530006.csv → 05530006.csv
# Copied: 99999999-05530007.csv → 05530007.csv
# Copied: 99999999-05530008.csv → 05530008.csv
# Copied: 99999999-05530009.csv → 05530009.csv
# Copied: 99999999-05530010.csv → 05530010.csv
# Copied: 99999999-05530011.csv → 05530011.csv
# Copied: 99999999-05530012.csv → 05530012.csv
# Copied: 99999999-05530013.csv → 05530013.csv
# Copied: 99999999-05530014.csv → 05530014.csv
# Copied: 99999999-05530015.csv → 05530015.csv
# Copied: 99999999-05530016.csv → 05530016.csv
# Copied: 99999999-05530017.csv → 05530017.csv
# Copied: 99999999-05530018.csv → 05530018.csv
# Copied: 99999999-05530019.csv → 05530019.csv
# Copied: 99999999-05530020.csv → 05530020.csv
# Copied: 99999999-05530021.csv → 05530021.csv
# Copied: 99999999-05530022.csv → 05530022.csv
# Copied: 99999999-05530023.csv → 05530023.csv
# Copied: 99999999-05530024.csv → 05530024.csv
# Copied: 99999999-05530025.csv → 05530025.csv
# Copied: 99999999-05530026.csv → 05530026.csv
# Copied: 99999999-05530027.csv → 05530027.csv
# Copied: 99999999-05530028.csv → 05530028.csv
# Copied: 99999999-05530029.csv → 05530029.csv
# Copied: 99999999-05530030.csv → 05530030.csv
# Copied: 99999999-05530031.csv → 05530031.csv
# Copied: 99999999-05530032.csv → 05530032.csv
# Copied: 99999999-05530033.csv → 05530033.csv
# Copied: 99999999-06780001.csv → 06780001.csv
# Copied: 99999999-06780002.csv → 06780002.csv
# Copied: 99999999-06780003.csv → 06780003.csv
# Copied: 99999999-06780004.csv → 06780004.csv
# Copied: 99999999-06780005.csv → 06780005.csv
# Copied: 99999999-06780006.csv → 06780006.csv
# Copied: 99999999-06780007.csv → 06780007.csv
# Copied: 99999999-06780008.csv → 06780008.csv
# Copied: 99999999-06780009.csv → 06780009.csv
# Copied: 99999999-06780010.csv → 06780010.csv
# Copied: 99999999-06780011.csv → 06780011.csv
# Copied: 99999999-06780012.csv → 06780012.csv
# Copied: 99999999-06780013.csv → 06780013.csv
# Copied: 99999999-06780014.csv → 06780014.csv
# Copied: 99999999-06780015.csv → 06780015.csv
# Copied: 99999999-06780016.csv → 06780016.csv
# Copied: 99999999-06780017.csv → 06780017.csv
# Copied: 99999999-06780018.csv → 06780018.csv
# Copied: 99999999-06780019.csv → 06780019.csv
# Copied: 99999999-06780020.csv → 06780020.csv
# Copied: 99999999-06780021.csv → 06780021.csv
# Copied: 99999999-06780022.csv → 06780022.csv
# Copied: 99999999-06780023.csv → 06780023.csv
# Copied: 99999999-06780024.csv → 06780024.csv
# Copied: 99999999-06780025.csv → 06780025.csv
# Copied: 99999999-06780026.csv → 06780026.csv
# Copied: 99999999-06780027.csv → 06780027.csv
# Copied: 99999999-06780028.csv → 06780028.csv
# Copied: 99999999-06780029.csv → 06780029.csv
# Copied: 99999999-06780030.csv → 06780030.csv
# Copied: 99999999-06780031.csv → 06780031.csv
# Copied: 99999999-06780032.csv → 06780032.csv
# Copied: 99999999-06780033.csv → 06780033.csv
# Copied: 99999999-06780034.csv → 06780034.csv
# Copied: 99999999-06780035.csv → 06780035.csv
# Copied: 99999999-06780036.csv → 06780036.csv
# Copied: 99999999-06780037.csv → 06780037.csv
# Copied: 99999999-06780038.csv → 06780038.csv
# Copied: 99999999-06780039.csv → 06780039.csv
# Copied: 99999999-06780040.csv → 06780040.csv
# Copied: 99999999-06780041.csv → 06780041.csv
# Copied: 99999999-06780042.csv → 06780042.csv
# Copied: 99999999-06780043.csv → 06780043.csv
# Copied: 99999999-06780044.csv → 06780044.csv
# Copied: 99999999-06780045.csv → 06780045.csv
# Copied: 99999999-06780046.csv → 06780046.csv
# Copied: 99999999-06780047.csv → 06780047.csv
# Copied: 99999999-06780048.csv → 06780048.csv
# Copied: 99999999-06780049.csv → 06780049.csv
# Copied: 99999999-06780050.csv → 06780050.csv
# Copied: 99999999-06780051.csv → 06780051.csv
# Copied: 99999999-06780052.csv → 06780052.csv
# Copied: 99999999-06780053.csv → 06780053.csv
# Copied: 99999999-06780054.csv → 06780054.csv
# Copied: 99999999-06780055.csv → 06780055.csv
# Copied: 99999999-06780056.csv → 06780056.csv
# Copied: 99999999-06780057.csv → 06780057.csv
# Copied: 99999999-06780058.csv → 06780058.csv
# Copied: 99999999-06780059.csv → 06780059.csv
# Copied: 99999999-06780060.csv → 06780060.csv
# Copied: 99999999-06780061.csv → 06780061.csv
# Copied: 99999999-06780062.csv → 06780062.csv
# Copied: 99999999-06800001.csv → 06800001.csv
# Copied: 99999999-06800002.csv → 06800002.csv
# Copied: 99999999-06800003.csv → 06800003.csv
# Copied: 99999999-06800004.csv → 06800004.csv
# Copied: 99999999-06800005.csv → 06800005.csv
# Copied: 99999999-06800006.csv → 06800006.csv
# Copied: 99999999-06800007.csv → 06800007.csv
# Copied: 99999999-06800008.csv → 06800008.csv
# Copied: 99999999-06800009.csv → 06800009.csv
# Copied: 99999999-06800010.csv → 06800010.csv
# Copied: 99999999-06800011.csv → 06800011.csv
# Copied: 99999999-06800012.csv → 06800012.csv
# Copied: 99999999-06800013.csv → 06800013.csv
# Copied: 99999999-06800014.csv → 06800014.csv
# Copied: 99999999-06800015.csv → 06800015.csv
# Copied: 99999999-06800016.csv → 06800016.csv
# Copied: 99999999-06800017.csv → 06800017.csv
# Copied: 99999999-06800018.csv → 06800018.csv
# Copied: 99999999-06800019.csv → 06800019.csv
# Copied: 99999999-06800020.csv → 06800020.csv
# Copied: 99999999-06800021.csv → 06800021.csv
# Copied: 99999999-06800022.csv → 06800022.csv
# Copied: 99999999-06800023.csv → 06800023.csv
# Copied: 99999999-06800024.csv → 06800024.csv
# Copied: 99999999-06800025.csv → 06800025.csv
# Copied: 99999999-06800026.csv → 06800026.csv
# Copied: 99999999-06800027.csv → 06800027.csv
# Copied: 99999999-06800028.csv → 06800028.csv
# Copied: 99999999-06800029.csv → 06800029.csv
# Copied: 99999999-06800030.csv → 06800030.csv
# Copied: 99999999-06800031.csv → 06800031.csv
# Copied: 99999999-06800032.csv → 06800032.csv
# Copied: 99999999-06800033.csv → 06800033.csv
# Copied: 99999999-06800034.csv → 06800034.csv
# Copied: 99999999-06800035.csv → 06800035.csv
# Copied: 99999999-06800036.csv → 06800036.csv
# Copied: 99999999-06800037.csv → 06800037.csv
# Copied: 99999999-06800038.csv → 06800038.csv
# Copied: 99999999-06800039.csv → 06800039.csv
# Copied: 99999999-06800040.csv → 06800040.csv
# Copied: 99999999-06800041.csv → 06800041.csv
# Copied: 99999999-06800042.csv → 06800042.csv
# Copied: 99999999-06800043.csv → 06800043.csv
# Copied: 99999999-06800044.csv → 06800044.csv
# Copied: 99999999-06800045.csv → 06800045.csv
# Copied: 99999999-06800046.csv → 06800046.csv
# Copied: 99999999-06800047.csv → 06800047.csv
# Copied: 99999999-06800048.csv → 06800048.csv
# Copied: 99999999-06800049.csv → 06800049.csv
# Copied: 99999999-06800050.csv → 06800050.csv
# Copied: 99999999-06800051.csv → 06800051.csv
# Copied: 99999999-06800052.csv → 06800052.csv
# Copied: 99999999-06800053.csv → 06800053.csv
# Copied: 99999999-06800054.csv → 06800054.csv
# Copied: 99999999-06800055.csv → 06800055.csv
# Copied: 99999999-06800056.csv → 06800056.csv
# Copied: 99999999-06800057.csv → 06800057.csv
# Copied: 99999999-06800058.csv → 06800058.csv
# Copied: 99999999-06800059.csv → 06800059.csv
# Copied: 99999999-06830001.csv → 06830001.csv
# Copied: 99999999-06830002.csv → 06830002.csv
# Copied: 99999999-06830003.csv → 06830003.csv
# Copied: 99999999-06830004.csv → 06830004.csv
# Copied: 99999999-06830005.csv → 06830005.csv
# Copied: 99999999-06830006.csv → 06830006.csv
# Copied: 99999999-06830007.csv → 06830007.csv
# Copied: 99999999-06830008.csv → 06830008.csv
# Copied: 99999999-06830009.csv → 06830009.csv
# Copied: 99999999-06830010.csv → 06830010.csv
# Copied: 99999999-06830011.csv → 06830011.csv
# Copied: 99999999-06830012.csv → 06830012.csv
# Copied: 99999999-06830013.csv → 06830013.csv
# Copied: 99999999-06830014.csv → 06830014.csv
# Copied: 99999999-06830015.csv → 06830015.csv
# Copied: 99999999-06830016.csv → 06830016.csv
# Copied: 99999999-06830017.csv → 06830017.csv
# Copied: 99999999-06830018.csv → 06830018.csv
# Copied: 99999999-06830019.csv → 06830019.csv
# Copied: 99999999-06830020.csv → 06830020.csv
# Copied: 99999999-06830021.csv → 06830021.csv
# Copied: 99999999-06830022.csv → 06830022.csv
# Copied: 99999999-06830023.csv → 06830023.csv
# Copied: 99999999-06830024.csv → 06830024.csv
# Copied: 99999999-06830025.csv → 06830025.csv
# Copied: 99999999-06830026.csv → 06830026.csv
# Copied: 99999999-06830027.csv → 06830027.csv
# Copied: 99999999-06830028.csv → 06830028.csv
# Copied: 99999999-06830029.csv → 06830029.csv
# Copied: 99999999-06830030.csv → 06830030.csv
# Copied: 99999999-06830031.csv → 06830031.csv
# Copied: 99999999-06830032.csv → 06830032.csv
# Copied: 99999999-06830033.csv → 06830033.csv
# Copied: 99999999-06830034.csv → 06830034.csv
# Copied: 99999999-06830035.csv → 06830035.csv
# Copied: 99999999-06830036.csv → 06830036.csv
# Copied: 99999999-06830037.csv → 06830037.csv
# Copied: 99999999-06830038.csv → 06830038.csv
# Copied: 99999999-06830039.csv → 06830039.csv
# Copied: 99999999-06830040.csv → 06830040.csv
# Copied: 99999999-06830041.csv → 06830041.csv
# Copied: 99999999-06830042.csv → 06830042.csv
# Copied: 99999999-06830043.csv → 06830043.csv
# Copied: 99999999-06830044.csv → 06830044.csv
# Copied: 99999999-06830045.csv → 06830045.csv
# Copied: 99999999-06830046.csv → 06830046.csv
# Copied: 99999999-06830047.csv → 06830047.csv
# Copied: 99999999-06830048.csv → 06830048.csv
# Copied: 99999999-06830049.csv → 06830049.csv
# Copied: 99999999-06830050.csv → 06830050.csv
# Copied: 99999999-06830051.csv → 06830051.csv
# Copied: 99999999-06830052.csv → 06830052.csv
# Copied: 99999999-06830053.csv → 06830053.csv
# Copied: 99999999-06830054.csv → 06830054.csv
# Copied: 99999999-06830055.csv → 06830055.csv
# Copied: 99999999-06830056.csv → 06830056.csv
# Copied: 99999999-06830057.csv → 06830057.csv
# Copied: 99999999-06830058.csv → 06830058.csv
# Copied: 99999999-06830059.csv → 06830059.csv
# Copied: 99999999-06830060.csv → 06830060.csv
# Copied: 99999999-06830061.csv → 06830061.csv
# Copied: 99999999-06830062.csv → 06830062.csv
# Copied: 99999999-06830063.csv → 06830063.csv
# Copied: 99999999-06830064.csv → 06830064.csv
# Copied: 99999999-06830065.csv → 06830065.csv
# Copied: 99999999-06830066.csv → 06830066.csv
# Copied: 99999999-06830067.csv → 06830067.csv
# Copied: 99999999-06830068.csv → 06830068.csv
# Copied: 99999999-06830069.csv → 06830069.csv
# Copied: 99999999-06830070.csv → 06830070.csv
# Copied: 99999999-06830071.csv → 06830071.csv
# Copied: 99999999-06830072.csv → 06830072.csv
# Copied: 99999999-06830073.csv → 06830073.csv
# Copied: 99999999-06830074.csv → 06830074.csv
# Copied: 99999999-06830075.csv → 06830075.csv
# Copied: 99999999-06830076.csv → 06830076.csv
# Copied: 99999999-06830077.csv → 06830077.csv
# Copied: 99999999-06830078.csv → 06830078.csv
# Copied: 99999999-07460001.csv → 07460001.csv
# Copied: 99999999-07460002.csv → 07460002.csv
# Copied: 99999999-07460003.csv → 07460003.csv
# Copied: 99999999-07460004.csv → 07460004.csv
# Copied: 99999999-07460005.csv → 07460005.csv
# Copied: 99999999-07460006.csv → 07460006.csv
# Copied: 99999999-07460007.csv → 07460007.csv
# Copied: 99999999-07460008.csv → 07460008.csv
# Copied: 99999999-07460009.csv → 07460009.csv
# Copied: 99999999-07460010.csv → 07460010.csv
# Copied: 99999999-07460011.csv → 07460011.csv
# Copied: 99999999-07460012.csv → 07460012.csv
# Copied: 99999999-07460013.csv → 07460013.csv
# Copied: 99999999-07460014.csv → 07460014.csv
# Copied: 99999999-07460015.csv → 07460015.csv
# Copied: 99999999-07460016.csv → 07460016.csv
# Copied: 99999999-07460017.csv → 07460017.csv
# Copied: 99999999-07460018.csv → 07460018.csv
# Copied: 99999999-07460019.csv → 07460019.csv
# Copied: 99999999-07460020.csv → 07460020.csv
# Copied: 99999999-07460021.csv → 07460021.csv
# Copied: 99999999-07460022.csv → 07460022.csv
# Copied: 99999999-07460023.csv → 07460023.csv
# Copied: 99999999-10190001.csv → 10190001.csv
# Copied: 99999999-10190002.csv → 10190002.csv
# Copied: 99999999-10190003.csv → 10190003.csv
# Copied: 99999999-10190004.csv → 10190004.csv
# Copied: 99999999-10190005.csv → 10190005.csv
# Copied: 99999999-10190006.csv → 10190006.csv
# Copied: 99999999-10190007.csv → 10190007.csv
# Copied: 99999999-10190008.csv → 10190008.csv
# Copied: 99999999-10190009.csv → 10190009.csv
# Copied: 99999999-10190010.csv → 10190010.csv
# Copied: 99999999-10190011.csv → 10190011.csv
# Copied: 99999999-10190012.csv → 10190012.csv
# Copied: 99999999-10190013.csv → 10190013.csv
# Copied: 99999999-10190014.csv → 10190014.csv
# Copied: 99999999-10190015.csv → 10190015.csv
# Copied: 99999999-10190016.csv → 10190016.csv
# Copied: 99999999-10190017.csv → 10190017.csv
# Copied: 99999999-10190018.csv → 10190018.csv
# Copied: 99999999-10190019.csv → 10190019.csv
# Copied: 99999999-10190020.csv → 10190020.csv
# Copied: 99999999-10190021.csv → 10190021.csv
# Copied: 99999999-10190022.csv → 10190022.csv
# Copied: 99999999-10190023.csv → 10190023.csv
# Copied: 99999999-10190024.csv → 10190024.csv
# Copied: 99999999-10190025.csv → 10190025.csv
# Copied: 99999999-10190026.csv → 10190026.csv
# Copied: 99999999-10190027.csv → 10190027.csv
# Copied: 99999999-10190028.csv → 10190028.csv
# Copied: 99999999-10190029.csv → 10190029.csv
# Copied: 99999999-10190030.csv → 10190030.csv
# Copied: 99999999-10190031.csv → 10190031.csv
# Copied: 99999999-10190032.csv → 10190032.csv
# Copied: 99999999-10190033.csv → 10190033.csv
# Copied: 99999999-10190034.csv → 10190034.csv
# Copied: 99999999-10190035.csv → 10190035.csv
# Copied: 99999999-10190036.csv → 10190036.csv
# Copied: 99999999-10190037.csv → 10190037.csv
# Copied: 99999999-10190038.csv → 10190038.csv
# Copied: 99999999-10190039.csv → 10190039.csv
# Copied: 99999999-10190040.csv → 10190040.csv
# Copied: 99999999-10190041.csv → 10190041.csv
# Copied: 99999999-10190042.csv → 10190042.csv
# Copied: 99999999-10190043.csv → 10190043.csv
# Copied: 99999999-10190044.csv → 10190044.csv
# Copied: 99999999-10190045.csv → 10190045.csv
# Copied: 99999999-10190046.csv → 10190046.csv
# Copied: 99999999-10190047.csv → 10190047.csv
# Copied: 99999999-10190048.csv → 10190048.csv
# Copied: 99999999-10190049.csv → 10190049.csv
# Copied: 99999999-10590001.csv → 10590001.csv
# Copied: 99999999-10590002.csv → 10590002.csv
# Copied: 99999999-10590003.csv → 10590003.csv
# Copied: 99999999-10590004.csv → 10590004.csv
# Copied: 99999999-10590005.csv → 10590005.csv
# Copied: 99999999-10590006.csv → 10590006.csv
# Copied: 99999999-10590007.csv → 10590007.csv
# Copied: 99999999-10590008.csv → 10590008.csv
# Copied: 99999999-10590009.csv → 10590009.csv
# Copied: 99999999-10590010.csv → 10590010.csv
# Copied: 99999999-10590011.csv → 10590011.csv
# Copied: 99999999-10590012.csv → 10590012.csv
# Copied: 99999999-10590013.csv → 10590013.csv
# Copied: 99999999-10590014.csv → 10590014.csv
# Copied: 99999999-10590015.csv → 10590015.csv
# Copied: 99999999-10590016.csv → 10590016.csv
# Copied: 99999999-10590017.csv → 10590017.csv
# Copied: 99999999-10590018.csv → 10590018.csv
# Copied: 99999999-10590019.csv → 10590019.csv
# Copied: 99999999-10590020.csv → 10590020.csv
# Copied: 99999999-10590021.csv → 10590021.csv
# Copied: 99999999-10590022.csv → 10590022.csv
# Copied: 99999999-10590023.csv → 10590023.csv
# Copied: 99999999-10590024.csv → 10590024.csv
# Copied: 99999999-10590025.csv → 10590025.csv
# Copied: 99999999-10590026.csv → 10590026.csv
# Copied: 99999999-10590027.csv → 10590027.csv
# Copied: 99999999-10590028.csv → 10590028.csv
# Copied: 99999999-10590029.csv → 10590029.csv
# Copied: 99999999-10590030.csv → 10590030.csv
# Copied: 99999999-10590031.csv → 10590031.csv
# Copied: 99999999-10590032.csv → 10590032.csv
# Copied: 99999999-10590033.csv → 10590033.csv
# Copied: 99999999-10590034.csv → 10590034.csv
# Copied: 99999999-10590035.csv → 10590035.csv
# Copied: 99999999-10590036.csv → 10590036.csv
# Copied: 99999999-10590037.csv → 10590037.csv
# Copied: 99999999-10590038.csv → 10590038.csv
# Copied: 99999999-10590039.csv → 10590039.csv
# Copied: 99999999-10590040.csv → 10590040.csv
# Copied: 99999999-10590041.csv → 10590041.csv
# Copied: 99999999-10590042.csv → 10590042.csv
# Copied: 99999999-10590043.csv → 10590043.csv
# Copied: 99999999-10590044.csv → 10590044.csv
# Copied: 99999999-10590045.csv → 10590045.csv
# Copied: 99999999-10590046.csv → 10590046.csv
# Copied: 99999999-10590047.csv → 10590047.csv
# Copied: 99999999-10590048.csv → 10590048.csv
# Copied: 99999999-10590049.csv → 10590049.csv
# Copied: 99999999-10590050.csv → 10590050.csv
# Copied: 99999999-10590051.csv → 10590051.csv
# Copied: 99999999-10590052.csv → 10590052.csv
# Copied: 99999999-10590053.csv → 10590053.csv
# Copied: 99999999-10590054.csv → 10590054.csv
# Copied: 99999999-10590055.csv → 10590055.csv
# Copied: 99999999-10590056.csv → 10590056.csv
# Copied: 99999999-10590057.csv → 10590057.csv
# Copied: 99999999-10590058.csv → 10590058.csv
# Copied: 99999999-10590059.csv → 10590059.csv
# Copied: 99999999-10590060.csv → 10590060.csv
# Copied: 99999999-10590061.csv → 10590061.csv
# Copied: 99999999-10590062.csv → 10590062.csv
# Copied: 99999999-10590063.csv → 10590063.csv
# Copied: 99999999-10590064.csv → 10590064.csv
# Copied: 99999999-10590065.csv → 10590065.csv
# Copied: 99999999-10590066.csv → 10590066.csv
# Copied: 99999999-10590067.csv → 10590067.csv
# Copied: 99999999-10590068.csv → 10590068.csv
# Copied: 99999999-10590069.csv → 10590069.csv
# Copied: 99999999-10590070.csv → 10590070.csv
# Copied: 99999999-10590071.csv → 10590071.csv
# Copied: 99999999-10590072.csv → 10590072.csv
# Copied: 99999999-10590073.csv → 10590073.csv
# Copied: 99999999-10590074.csv → 10590074.csv
# Copied: 99999999-10590075.csv → 10590075.csv
# Copied: 99999999-10590076.csv → 10590076.csv
# Copied: 99999999-10590077.csv → 10590077.csv
# Copied: 99999999-10590078.csv → 10590078.csv
# Copied: 99999999-10590079.csv → 10590079.csv
# Copied: 99999999-10590080.csv → 10590080.csv
# Copied: 99999999-10590081.csv → 10590081.csv
# Copied: 99999999-10590082.csv → 10590082.csv
# Copied: 99999999-10590083.csv → 10590083.csv
# Copied: 99999999-10590084.csv → 10590084.csv
# Copied: 99999999-10590085.csv → 10590085.csv
# Copied: 99999999-10590086.csv → 10590086.csv
# Copied: 99999999-10590087.csv → 10590087.csv
# Copied: 99999999-10590088.csv → 10590088.csv
# Copied: 99999999-10590089.csv → 10590089.csv
# Copied: 99999999-10590090.csv → 10590090.csv
# Copied: 99999999-10590091.csv → 10590091.csv
# Copied: 99999999-10590092.csv → 10590092.csv
# Copied: 99999999-10590093.csv → 10590093.csv
# Copied: 99999999-10590094.csv → 10590094.csv
# Copied: 99999999-10590095.csv → 10590095.csv
# Copied: 99999999-10590096.csv → 10590096.csv
# Copied: 99999999-10590097.csv → 10590097.csv
# Copied: 99999999-10590098.csv → 10590098.csv
# Copied: 99999999-10590099.csv → 10590099.csv
# Copied: 99999999-10590100.csv → 10590100.csv
# Copied: 99999999-10590101.csv → 10590101.csv
# Copied: 99999999-10590102.csv → 10590102.csv
# Copied: 99999999-10590103.csv → 10590103.csv
# Copied: 99999999-10590104.csv → 10590104.csv
# Copied: 99999999-10590105.csv → 10590105.csv
# Copied: 99999999-10590106.csv → 10590106.csv
# Copied: 99999999-10590107.csv → 10590107.csv
# Copied: 99999999-10590108.csv → 10590108.csv
# Copied: 99999999-10590109.csv → 10590109.csv
# Copied: 99999999-10590110.csv → 10590110.csv
# Copied: 99999999-10590111.csv → 10590111.csv
# Copied: 99999999-10590112.csv → 10590112.csv
# Copied: 99999999-10590113.csv → 10590113.csv
# Copied: 99999999-10590114.csv → 10590114.csv
# Copied: 99999999-10590115.csv → 10590115.csv
# Copied: 99999999-10590116.csv → 10590116.csv
# Copied: 99999999-10590117.csv → 10590117.csv
# Copied: 99999999-10590118.csv → 10590118.csv
# Copied: 99999999-10590119.csv → 10590119.csv
# Copied: 99999999-10590120.csv → 10590120.csv
# Copied: 99999999-10590121.csv → 10590121.csv
# Copied: 99999999-10590122.csv → 10590122.csv
# Copied: 99999999-10590123.csv → 10590123.csv
# Copied: 99999999-10590124.csv → 10590124.csv
# Copied: 99999999-10590125.csv → 10590125.csv
# Copied: 99999999-10590126.csv → 10590126.csv
# Copied: 99999999-10590127.csv → 10590127.csv
# Copied: 99999999-10590128.csv → 10590128.csv
# Copied: 99999999-10590129.csv → 10590129.csv
# Copied: 99999999-14760001.csv → 14760001.csv
# Copied: 99999999-14760002.csv → 14760002.csv
# Copied: 99999999-14760003.csv → 14760003.csv
# Copied: 99999999-14760004.csv → 14760004.csv
# Copied: 99999999-14760005.csv → 14760005.csv
# Copied: 99999999-14760006.csv → 14760006.csv
# Copied: 99999999-14760007.csv → 14760007.csv
# Copied: 99999999-14760008.csv → 14760008.csv
# Copied: 99999999-14760009.csv → 14760009.csv
# Copied: 99999999-14760010.csv → 14760010.csv
# Copied: 99999999-14760011.csv → 14760011.csv
# Copied: 99999999-14760012.csv → 14760012.csv
# Copied: 99999999-14760013.csv → 14760013.csv
# Copied: 99999999-14760014.csv → 14760014.csv
# Copied: 99999999-14760015.csv → 14760015.csv
# Copied: 99999999-14760016.csv → 14760016.csv
# Copied: 99999999-14760017.csv → 14760017.csv
# Copied: 99999999-14760018.csv → 14760018.csv
# Copied: 99999999-14760019.csv → 14760019.csv
# Copied: 99999999-14760020.csv → 14760020.csv
# Copied: 99999999-14760021.csv → 14760021.csv
# Copied: 99999999-14760022.csv → 14760022.csv
# Copied: 99999999-14760023.csv → 14760023.csv
# Copied: 99999999-14760024.csv → 14760024.csv
# Copied: 99999999-14760025.csv → 14760025.csv
# Copied: 99999999-14760026.csv → 14760026.csv
# Copied: 99999999-14760027.csv → 14760027.csv
# Copied: 99999999-14760028.csv → 14760028.csv
# Copied: 99999999-14760029.csv → 14760029.csv
# Copied: 99999999-14760030.csv → 14760030.csv
# Copied: 99999999-14760031.csv → 14760031.csv
# Copied: 99999999-14760032.csv → 14760032.csv
# Copied: 99999999-14760033.csv → 14760033.csv
# Copied: 99999999-14760034.csv → 14760034.csv
# Copied: 99999999-14760035.csv → 14760035.csv
# Copied: 99999999-14760036.csv → 14760036.csv
# Copied: 99999999-14760037.csv → 14760037.csv
# Copied: 99999999-14760038.csv → 14760038.csv
# Copied: 99999999-14760039.csv → 14760039.csv
# Copied: 99999999-14760040.csv → 14760040.csv
# Copied: 99999999-14760041.csv → 14760041.csv
# Copied: 99999999-14760042.csv → 14760042.csv
# Copied: 99999999-14760043.csv → 14760043.csv
# Copied: 99999999-14760044.csv → 14760044.csv
# Copied: 99999999-14760045.csv → 14760045.csv
# Copied: 99999999-14760046.csv → 14760046.csv
# Copied: 99999999-14760047.csv → 14760047.csv
# Copied: 99999999-14760048.csv → 14760048.csv
# Copied: 99999999-14760049.csv → 14760049.csv
# Copied: 99999999-14760050.csv → 14760050.csv
# Copied: 99999999-14760051.csv → 14760051.csv
# Copied: 99999999-14760052.csv → 14760052.csv
# Copied: 99999999-14760053.csv → 14760053.csv
# Copied: 99999999-14760054.csv → 14760054.csv
# Copied: 99999999-14760055.csv → 14760055.csv
# Copied: 99999999-14760056.csv → 14760056.csv
# Copied: 99999999-14760057.csv → 14760057.csv
# Copied: 99999999-14760058.csv → 14760058.csv
# Copied: 99999999-14760059.csv → 14760059.csv
# Copied: 99999999-15430001.csv → 15430001.csv
# Copied: 99999999-15430002.csv → 15430002.csv
# Copied: 99999999-15430003.csv → 15430003.csv
# Copied: 99999999-15430004.csv → 15430004.csv
# Copied: 99999999-15430005.csv → 15430005.csv
# Copied: 99999999-15430006.csv → 15430006.csv
# Copied: 99999999-15430007.csv → 15430007.csv
# Copied: 99999999-15430008.csv → 15430008.csv
# Copied: 99999999-15430009.csv → 15430009.csv
# Copied: 99999999-15430010.csv → 15430010.csv
# Copied: 99999999-15430011.csv → 15430011.csv
# Copied: 99999999-15430012.csv → 15430012.csv
# Copied: 99999999-15430013.csv → 15430013.csv
# Copied: 99999999-15430014.csv → 15430014.csv
# Copied: 99999999-15430015.csv → 15430015.csv
# Copied: 99999999-15430016.csv → 15430016.csv
# Copied: 99999999-15430017.csv → 15430017.csv
# Copied: 99999999-15430018.csv → 15430018.csv
# Copied: 99999999-15430019.csv → 15430019.csv
# Copied: 99999999-15430020.csv → 15430020.csv
# Copied: 99999999-15430021.csv → 15430021.csv
# Copied: 99999999-15430022.csv → 15430022.csv
# Copied: 99999999-15430023.csv → 15430023.csv
# Copied: 99999999-15430024.csv → 15430024.csv
# Copied: 99999999-15430025.csv → 15430025.csv
# Copied: 99999999-15430026.csv → 15430026.csv
# Copied: 99999999-15430027.csv → 15430027.csv
# Copied: 99999999-15430028.csv → 15430028.csv
# Copied: 99999999-15430029.csv → 15430029.csv
# Copied: 99999999-15430030.csv → 15430030.csv
# Copied: 99999999-15430031.csv → 15430031.csv
# Copied: 99999999-15430032.csv → 15430032.csv
# Copied: 99999999-15430033.csv → 15430033.csv
# Copied: 99999999-15430034.csv → 15430034.csv
# Copied: 99999999-15430035.csv → 15430035.csv
# Copied: 99999999-15430036.csv → 15430036.csv
# Copied: 99999999-15430037.csv → 15430037.csv
# Copied: 99999999-15430038.csv → 15430038.csv
# Copied: 99999999-15430039.csv → 15430039.csv
# Copied: 99999999-15430040.csv → 15430040.csv
# Copied: 99999999-15430041.csv → 15430041.csv
# Copied: 99999999-15430042.csv → 15430042.csv
# Copied: 99999999-15430043.csv → 15430043.csv
# Copied: 99999999-15430045.csv → 15430045.csv
# Copied: 99999999-15430046.csv → 15430046.csv
# Copied: 99999999-15430047.csv → 15430047.csv
# Copied: 99999999-15430048.csv → 15430048.csv
# Copied: 99999999-15430049.csv → 15430049.csv
# Copied: 99999999-15430050.csv → 15430050.csv
# Copied: 99999999-15430051.csv → 15430051.csv
# Copied: 99999999-15430052.csv → 15430052.csv
# Copied: 99999999-15430053.csv → 15430053.csv
# Copied: 99999999-15430054.csv → 15430054.csv
# Copied: 99999999-15430055.csv → 15430055.csv
# Copied: 99999999-15430056.csv → 15430056.csv
# Copied: 99999999-15430057.csv → 15430057.csv
# Copied: 99999999-15430058.csv → 15430058.csv
# Copied: 99999999-15430059.csv → 15430059.csv
# Copied: 99999999-15430060.csv → 15430060.csv
# Copied: 99999999-15430061.csv → 15430061.csv
# Copied: 99999999-15430062.csv → 15430062.csv
# Copied: 99999999-15430063.csv → 15430063.csv
# Copied: 99999999-15430064.csv → 15430064.csv
# Copied: 99999999-15430065.csv → 15430065.csv
# Copied: 99999999-15430066.csv → 15430066.csv
# Copied: 99999999-15430067.csv → 15430067.csv
# Copied: 99999999-15430068.csv → 15430068.csv
# Copied: 99999999-15430069.csv → 15430069.csv
# Copied: 99999999-15430070.csv → 15430070.csv
# Copied: 99999999-15430071.csv → 15430071.csv
# Copied: 99999999-15430072.csv → 15430072.csv
# Copied: 99999999-15430073.csv → 15430073.csv
# Copied: 99999999-15430074.csv → 15430074.csv
# Copied: 99999999-15430075.csv → 15430075.csv
# Copied: 99999999-15430076.csv → 15430076.csv
# Copied: 99999999-15430077.csv → 15430077.csv
# Copied: 99999999-15430078.csv → 15430078.csv
# Copied: 99999999-15430079.csv → 15430079.csv
# Copied: 99999999-15430080.csv → 15430080.csv
# Copied: 99999999-15430081.csv → 15430081.csv
# Copied: 99999999-15430082.csv → 15430082.csv
# Copied: 99999999-15430083.csv → 15430083.csv
# Copied: 99999999-15430084.csv → 15430084.csv
# Copied: 99999999-15430085.csv → 15430085.csv
# Copied: 99999999-15430086.csv → 15430086.csv
# Copied: 99999999-15430087.csv → 15430087.csv
# Copied: 99999999-15430088.csv → 15430088.csv
# Copied: 99999999-15430089.csv → 15430089.csv
# Copied: 99999999-15430090.csv → 15430090.csv
# Copied: 99999999-15430091.csv → 15430091.csv
# Copied: 99999999-15430092.csv → 15430092.csv
# Copied: 99999999-15430093.csv → 15430093.csv
# Copied: 99999999-15430094.csv → 15430094.csv
# Copied: 99999999-15430095.csv → 15430095.csv
# Copied: 99999999-15430096.csv → 15430096.csv
# Copied: 99999999-15430097.csv → 15430097.csv
# Copied: 99999999-15430098.csv → 15430098.csv
# Copied: 99999999-15430099.csv → 15430099.csv
# Copied: 99999999-15430100.csv → 15430100.csv
# Copied: 99999999-15430101.csv → 15430101.csv
# Copied: 99999999-15430102.csv → 15430102.csv
# Copied: 99999999-15430103.csv → 15430103.csv
# Copied: 99999999-15430104.csv → 15430104.csv
# Copied: 99999999-15430105.csv → 15430105.csv
# Copied: 99999999-15430106.csv → 15430106.csv
# Copied: 99999999-15430107.csv → 15430107.csv
# Copied: 99999999-15430108.csv → 15430108.csv
# Copied: 99999999-15430109.csv → 15430109.csv
# Copied: 99999999-15430110.csv → 15430110.csv
# Copied: 99999999-15430111.csv → 15430111.csv
# Copied: 99999999-15430112.csv → 15430112.csv
# Copied: 99999999-15430113.csv → 15430113.csv
# Copied: 99999999-15430114.csv → 15430114.csv
# Copied: 99999999-15430115.csv → 15430115.csv
# Copied: 99999999-15430116.csv → 15430116.csv
# Copied: 99999999-15430117.csv → 15430117.csv
# Copied: 99999999-15430118.csv → 15430118.csv
# Copied: 99999999-15430119.csv → 15430119.csv
# Copied: 99999999-15430120.csv → 15430120.csv
# Copied: 99999999-15430121.csv → 15430121.csv
# Copied: 99999999-15430122.csv → 15430122.csv
# Copied: 99999999-15430123.csv → 15430123.csv
# Copied: 99999999-15430124.csv → 15430124.csv
# Copied: 99999999-15430125.csv → 15430125.csv
# Copied: 99999999-15430126.csv → 15430126.csv
# Copied: 99999999-15710001.csv → 15710001.csv
# Copied: 99999999-15710002.csv → 15710002.csv
# Copied: 99999999-15710003.csv → 15710003.csv
# Copied: 99999999-15710004.csv → 15710004.csv
# Copied: 99999999-15710005.csv → 15710005.csv
# Copied: 99999999-15710006.csv → 15710006.csv
# Copied: 99999999-15710007.csv → 15710007.csv
# Copied: 99999999-15710008.csv → 15710008.csv
# Copied: 99999999-15710009.csv → 15710009.csv
# Copied: 99999999-15710010.csv → 15710010.csv
# Copied: 99999999-15710011.csv → 15710011.csv
# Copied: 99999999-15710012.csv → 15710012.csv
# Copied: 99999999-15710013.csv → 15710013.csv
# Copied: 99999999-15710014.csv → 15710014.csv
# Copied: 99999999-15710015.csv → 15710015.csv
# Copied: 99999999-15710016.csv → 15710016.csv
# Copied: 99999999-15710017.csv → 15710017.csv
# Copied: 99999999-15710018.csv → 15710018.csv
# Copied: 99999999-15710019.csv → 15710019.csv
# Copied: 99999999-15710020.csv → 15710020.csv
# Copied: 99999999-15710021.csv → 15710021.csv
# Copied: 99999999-15710022.csv → 15710022.csv
# Copied: 99999999-15710023.csv → 15710023.csv
# Copied: 99999999-15710024.csv → 15710024.csv
# Copied: 99999999-15710025.csv → 15710025.csv
# Copied: 99999999-15710026.csv → 15710026.csv
# Copied: 99999999-15710027.csv → 15710027.csv
# Copied: 99999999-15710028.csv → 15710028.csv
# Copied: 99999999-15710029.csv → 15710029.csv
# Copied: 99999999-15710030.csv → 15710030.csv
# Copied: 99999999-15710031.csv → 15710031.csv
# Copied: 99999999-15710032.csv → 15710032.csv
# Copied: 99999999-15710033.csv → 15710033.csv
# Copied: 99999999-15710034.csv → 15710034.csv
# Copied: 99999999-15710035.csv → 15710035.csv
# Copied: 99999999-15710036.csv → 15710036.csv
# Copied: 99999999-15710037.csv → 15710037.csv
# Copied: 99999999-15710038.csv → 15710038.csv
# Copied: 99999999-15710039.csv → 15710039.csv
# Copied: 99999999-15710040.csv → 15710040.csv
# Copied: 99999999-15710041.csv → 15710041.csv
# Copied: 99999999-15710042.csv → 15710042.csv
# Copied: 99999999-15710043.csv → 15710043.csv
# Copied: 99999999-15710044.csv → 15710044.csv
# Copied: 99999999-15710045.csv → 15710045.csv
# Copied: 99999999-15710046.csv → 15710046.csv
# Copied: 99999999-15710047.csv → 15710047.csv
# Copied: 99999999-15710048.csv → 15710048.csv
# Copied: 99999999-15710049.csv → 15710049.csv
# Copied: 99999999-15710051.csv → 15710051.csv
# Copied: 99999999-15710052.csv → 15710052.csv
# Copied: 99999999-15710053.csv → 15710053.csv
# Copied: 99999999-15710054.csv → 15710054.csv
# Copied: 99999999-15710055.csv → 15710055.csv
# Copied: 99999999-15710056.csv → 15710056.csv
# Copied: 99999999-15710057.csv → 15710057.csv
# Copied: 99999999-15710058.csv → 15710058.csv
# Copied: 99999999-15710059.csv → 15710059.csv
# Copied: 99999999-15710060.csv → 15710060.csv
# Copied: 99999999-15710061.csv → 15710061.csv
# Copied: 99999999-15710062.csv → 15710062.csv
# Copied: 99999999-15710063.csv → 15710063.csv
# Copied: 99999999-15710064.csv → 15710064.csv
# Copied: 99999999-15710066.csv → 15710066.csv
# Copied: 99999999-15710067.csv → 15710067.csv
# Copied: 99999999-15710068.csv → 15710068.csv
# Copied: 99999999-15710069.csv → 15710069.csv
# Copied: 99999999-22160001.csv → 22160001.csv
# Copied: 99999999-22160002.csv → 22160002.csv
# Copied: 99999999-22160003.csv → 22160003.csv
# Copied: 99999999-22160004.csv → 22160004.csv
# Copied: 99999999-22160005.csv → 22160005.csv
# Copied: 99999999-22160006.csv → 22160006.csv
# Copied: 99999999-22160007.csv → 22160007.csv
# Copied: 99999999-22160008.csv → 22160008.csv
# Copied: 99999999-22160009.csv → 22160009.csv
# Copied: 99999999-22160010.csv → 22160010.csv
# Copied: 99999999-22160011.csv → 22160011.csv
# Copied: 99999999-22160012.csv → 22160012.csv
# Copied: 99999999-22160013.csv → 22160013.csv
# Copied: 99999999-22160014.csv → 22160014.csv
# Copied: 99999999-22160015.csv → 22160015.csv
# Copied: 99999999-22160016.csv → 22160016.csv
# Copied: 99999999-22160017.csv → 22160017.csv
# Copied: 99999999-22160018.csv → 22160018.csv
# Copied: 99999999-22160019.csv → 22160019.csv
# Copied: 99999999-22160020.csv → 22160020.csv
# Copied: 99999999-22160021.csv → 22160021.csv
# Copied: 99999999-22160022.csv → 22160022.csv
# Copied: 99999999-22160023.csv → 22160023.csv
# Copied: 99999999-22160024.csv → 22160024.csv
# Copied: 99999999-22160025.csv → 22160025.csv
# Copied: 99999999-22160026.csv → 22160026.csv
# Copied: 99999999-22160027.csv → 22160027.csv
# Copied: 99999999-22160028.csv → 22160028.csv
# Copied: 99999999-22160029.csv → 22160029.csv
# Copied: 99999999-22160030.csv → 22160030.csv
# Copied: 99999999-22160031.csv → 22160031.csv
# Copied: 99999999-22160032.csv → 22160032.csv
# Copied: 99999999-22160033.csv → 22160033.csv
# Copied: 99999999-22160034.csv → 22160034.csv
# Copied: 99999999-22160035.csv → 22160035.csv
# Copied: 99999999-22160036.csv → 22160036.csv
# Copied: 99999999-22160037.csv → 22160037.csv
# Copied: 99999999-22160038.csv → 22160038.csv
# Copied: 99999999-22160039.csv → 22160039.csv
# Copied: 99999999-22160040.csv → 22160040.csv
# Copied: 99999999-22160041.csv → 22160041.csv
# Copied: 99999999-22160042.csv → 22160042.csv
# Copied: 99999999-22160043.csv → 22160043.csv
# Copied: 99999999-22160044.csv → 22160044.csv
# Copied: 99999999-22160045.csv → 22160045.csv
# Copied: 99999999-22160046.csv → 22160046.csv
# Copied: 99999999-22160047.csv → 22160047.csv
# Copied: 99999999-22160048.csv → 22160048.csv
# Copied: 99999999-22160049.csv → 22160049.csv
# Copied: 99999999-22160050.csv → 22160050.csv
# Copied: 99999999-22160051.csv → 22160051.csv
# Copied: 99999999-22160052.csv → 22160052.csv
# Copied: 99999999-22160053.csv → 22160053.csv
# Copied: 99999999-22160054.csv → 22160054.csv
# Copied: 99999999-22160055.csv → 22160055.csv
# Copied: 99999999-22160056.csv → 22160056.csv
# Copied: 99999999-22160057.csv → 22160057.csv
# Copied: 99999999-22160058.csv → 22160058.csv
# Copied: 99999999-22160059.csv → 22160059.csv
# Copied: 99999999-22160060.csv → 22160060.csv
# Copied: 99999999-22160061.csv → 22160061.csv
# Copied: 99999999-22160062.csv → 22160062.csv
# Copied: 99999999-22160063.csv → 22160063.csv
# Copied: 99999999-22160064.csv → 22160064.csv
# Copied: 99999999-22160065.csv → 22160065.csv
# Copied: 99999999-22160066.csv → 22160066.csv
# Copied: 99999999-22160067.csv → 22160067.csv
# Copied: 99999999-22160068.csv → 22160068.csv
# Copied: 99999999-22160069.csv → 22160069.csv
# Copied: 99999999-22160070.csv → 22160070.csv
# Copied: 99999999-22160071.csv → 22160071.csv
# Copied: 99999999-22160072.csv → 22160072.csv
# Copied: 99999999-22160073.csv → 22160073.csv
# Copied: 99999999-22160074.csv → 22160074.csv
# Copied: 99999999-22160075.csv → 22160075.csv
# Copied: 99999999-22160076.csv → 22160076.csv
# Copied: 99999999-22360001.csv → 22360001.csv
# Copied: 99999999-22360002.csv → 22360002.csv
# Copied: 99999999-22360003.csv → 22360003.csv
# Copied: 99999999-22360004.csv → 22360004.csv
# Copied: 99999999-22360005.csv → 22360005.csv
# Copied: 99999999-22360006.csv → 22360006.csv
# Copied: 99999999-22360007.csv → 22360007.csv
# Copied: 99999999-22360008.csv → 22360008.csv
# Copied: 99999999-22360009.csv → 22360009.csv
# Copied: 99999999-22360010.csv → 22360010.csv
# Copied: 99999999-22360011.csv → 22360011.csv
# Copied: 99999999-22360012.csv → 22360012.csv
# Copied: 99999999-22360013.csv → 22360013.csv
# Copied: 99999999-22360014.csv → 22360014.csv
# Copied: 99999999-22360017.csv → 22360017.csv
# Copied: 99999999-22360018.csv → 22360018.csv
# Copied: 99999999-22360019.csv → 22360019.csv
# Copied: 99999999-22360020.csv → 22360020.csv
# Copied: 99999999-22360021.csv → 22360021.csv
# Copied: 99999999-22360022.csv → 22360022.csv
# Copied: 99999999-22360023.csv → 22360023.csv
# Copied: 99999999-22360024.csv → 22360024.csv
# Copied: 99999999-22360025.csv → 22360025.csv
# Copied: 99999999-22360026.csv → 22360026.csv
# Copied: 99999999-22360027.csv → 22360027.csv
# Copied: 99999999-22360028.csv → 22360028.csv
# Copied: 99999999-22360029.csv → 22360029.csv
# Copied: 99999999-22360030.csv → 22360030.csv
# Copied: 99999999-22360031.csv → 22360031.csv
# Copied: 99999999-22360032.csv → 22360032.csv
# Copied: 99999999-22360033.csv → 22360033.csv
# Copied: 99999999-22360034.csv → 22360034.csv
# Copied: 99999999-22360035.csv → 22360035.csv
# Copied: 99999999-22360036.csv → 22360036.csv
# Copied: 99999999-22360041.csv → 22360041.csv
# Copied: 99999999-22360043.csv → 22360043.csv
# Copied: 99999999-22360044.csv → 22360044.csv
# Copied: 99999999-22360045.csv → 22360045.csv
# Copied: 99999999-22360046.csv → 22360046.csv
# Copied: 99999999-22360047.csv → 22360047.csv
# Copied: 99999999-22360048.csv → 22360048.csv
# Copied: 99999999-22360049.csv → 22360049.csv
# Copied: 99999999-22360050.csv → 22360050.csv
# Copied: 99999999-22360051.csv → 22360051.csv
# Copied: 99999999-22360052.csv → 22360052.csv
# Copied: 99999999-22360053.csv → 22360053.csv
# Copied: 99999999-22360054.csv → 22360054.csv
# Copied: 99999999-22360055.csv → 22360055.csv
# Copied: 99999999-22360056.csv → 22360056.csv
# Copied: 99999999-22360057.csv → 22360057.csv
# Copied: 99999999-22360058.csv → 22360058.csv
# Copied: 99999999-22360059.csv → 22360059.csv
# Copied: 99999999-22360060.csv → 22360060.csv
# Copied: 99999999-22360061.csv → 22360061.csv

# %%
import os
import json
import random
from collections import defaultdict

# 두 클래스 디렉토리
bl_dir = "/esail4/heeju/REGRESSION/Point-M2AE/data/segmentation2/00000000"

# 출력 디렉토리
output_dir = "/esail4/heeju/REGRESSION/Point-M2AE/data/segmentation2/classified_json_grouped"
os.makedirs(output_dir, exist_ok=True)

# 모든 파일 로드 및 그룹화 (앞 4자리 기준)
file_groups = defaultdict(list)

for file in os.listdir(bl_dir):
    if not file.endswith(".csv"):
        continue
    group_key = file[:4]  # 앞 4자리 기준 그룹화
    path = f"segmentation2/00000000/{os.path.splitext(file)[0]}"
    file_groups[group_key].append(path)


# 그룹 키들을 무작위로 섞음
group_keys = list(file_groups.keys())
random.shuffle(group_keys)

# 그룹 단위로 7:1:1:1 분할
n = len(group_keys)
train_keys = group_keys[: int(n * 0.7)]
test_keys  = group_keys[int(n * 0.7) : int(n * 0.8)]
val_keys   = group_keys[int(n * 0.8) : int(n * 0.9)]
inf_keys   = group_keys[:]

# 키 기반으로 전체 파일 리스트 생성
train_paths = [path for key in train_keys for path in file_groups[key]]
test_paths  = [path for key in test_keys  for path in file_groups[key]]
val_paths   = [path for key in val_keys   for path in file_groups[key]]
inf_paths   = [path for key in inf_keys   for path in file_groups[key]]

# 저장 함수
def save_json(data, filename):
    with open(os.path.join(output_dir, filename), "w") as f:
        json.dump(data, f, indent=4)

# 저장 실행
save_json(train_paths, "leafwood_data_train.json")
save_json(test_paths,  "leafwood_data_test.json")
save_json(val_paths,   "leafwood_data_val.json")
save_json(inf_paths,   "leafwood_data_inference.json")

# 출력
print(f"Train groups : {len(train_keys)}")
print(f"Test  groups : {len(test_keys)}")
print(f"Val   groups : {len(val_keys)}")
print(f"Infer groups : {len(inf_keys)}")
print(f"Saved to     : {output_dir}")
# Out:
# Train groups : 19
# Test  groups : 3
# Val   groups : 3
# Infer groups : 28
# Saved to     : /esail4/heeju/REGRESSION/Point-M2AE/data/segmentation2/classified_json_grouped

# %% [markdown]
# ### json for 2 dir

# %%
import os
import json
import random
from collections import defaultdict

# 재현성 고정 (원하시면 바꾸세요)
random.seed(42)

# 경로 설정
data_root = "/esail4/heeju/REGRESSION/Point-M2AE/data"
base_dir  = os.path.join(data_root, "06masked")   # ← occluded_inf 기준
class_dirs = ["22222222", "33333333"]                 # 두 클래스 폴더
output_dir = os.path.join(base_dir, "classified_json_grouped")
os.makedirs(output_dir, exist_ok=True)

# 1) 파일 수집 및 앞 4자리 기준 그룹핑
file_groups = defaultdict(list)  # key: 앞 4자리, val: [상대경로들]
total_files = 0

for cls in class_dirs:
    cls_dir = os.path.join(base_dir, cls)
    if not os.path.isdir(cls_dir):
        print(f"[WARN] 디렉토리 없음: {cls_dir}")
        continue

    for file in os.listdir(cls_dir):
        if not file.endswith(".csv"):
            continue
        total_files += 1
        group_key = file[:4]  # 앞 4자리
        stem = os.path.splitext(file)[0]
        rel_path = f"06masked/{cls}/{stem}"  # ← occluded_inf로 경로 프리픽스
        file_groups[group_key].append(rel_path)

print(f"[INFO] 총 CSV 파일 수: {total_files}")
print(f"[INFO] 그룹 수(앞4자리): {len(file_groups)}")

# 2) 그룹 키 셔플 + 7:1:1:1 분할
group_keys = list(file_groups.keys())
random.shuffle(group_keys)

n = len(group_keys)
train_keys = group_keys[: int(n * 0.7)]
test_keys  = group_keys[int(n * 0.7) : int(n * 0.8)]
val_keys   = group_keys[int(n * 0.8) : int(n * 0.9)]
inf_keys   = group_keys[:]  # 전체

# 3) 키 기반 경로 펼치기
train_paths = [p for k in train_keys for p in file_groups[k]]
test_paths  = [p for k in test_keys  for p in file_groups[k]]
val_paths   = [p for k in val_keys   for p in file_groups[k]]
inf_paths   = [p for k in inf_keys   for p in file_groups[k]]

# 4) 저장 함수
def save_json(data, filename):
    with open(os.path.join(output_dir, filename), "w") as f:
        json.dump(data, f, indent=4)

# 5) 저장
save_json(train_paths, "leafwood_data_train.json")
save_json(test_paths,  "leafwood_data_test.json")
save_json(val_paths,   "leafwood_data_val.json")
save_json(inf_paths,   "leafwood_data_inference.json")

# 6) 로그
print(f"Train groups : {len(train_keys)}  | files: {len(train_paths)}")
print(f"Test  groups : {len(test_keys)}   | files: {len(test_paths)}")
print(f"Val   groups : {len(val_keys)}    | files: {len(val_paths)}")
print(f"Infer groups : {len(inf_keys)}    | files: {len(inf_paths)}")
print(f"Saved to     : {output_dir}")
# Out:
# [INFO] 총 CSV 파일 수: 24
# [INFO] 그룹 수(앞4자리): 24
# Train groups : 16  | files: 16
# Test  groups : 3   | files: 3
# Val   groups : 2    | files: 2
# Infer groups : 24    | files: 24
# Saved to     : /esail4/heeju/REGRESSION/Point-M2AE/data/06masked/classified_json_grouped

# %% [markdown]
# ### merging

# %%
import os
import pandas as pd
from collections import defaultdict

# 입력 및 출력 경로
src_dir = '/esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001'
output_dir = os.path.join(src_dir, 'merged_noheader')
os.makedirs(output_dir, exist_ok=True)

# 파일 그룹핑 (앞 4자리)
grouped_files = defaultdict(list)

for filename in os.listdir(src_dir):
    if filename.endswith('.csv'):
        key = filename[:4]  # 앞 4자리 기준
        grouped_files[key].append(filename)

# 그룹별 수직 병합
for key, files in grouped_files.items():
    dfs = []
    for file in sorted(files):
        path = os.path.join(src_dir, file)
        df = pd.read_csv(path, header=None)  # 헤더가 없으므로 header=None
        dfs.append(df)

    merged_df = pd.concat(dfs, axis=0, ignore_index=True)  # 수직 결합
    output_path = os.path.join(output_dir, f"{key}_merged.csv")
    merged_df.to_csv(output_path, index=False, header=False)  # header도 저장하지 않음

    print(f"Saved: {output_path} with {len(merged_df)} rows")
# Out:
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/0553_merged.csv with 189715 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/0678_merged.csv with 1429084 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/0680_merged.csv with 1375773 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/0683_merged.csv with 1674596 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/0746_merged.csv with 416870 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/1019_merged.csv with 468835 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/1059_merged.csv with 1676077 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/1476_merged.csv with 1142147 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/1543_merged.csv with 1912040 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/1571_merged.csv with 613212 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/2216_merged.csv with 261280 rows
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/segmentation2/comb1_result_csv_0826/00000001/merged_noheader/2236_merged.csv with 56237 rows

# %%
import os
import pandas as pd

# 입력 및 출력 경로
input_dir = '/esail4/heeju/REGRESSION/Point-M2AE/segmentation2/result_csv_eval0820_2/00000000/merged_noheader'
output_dir = '/esail4/heeju/PoinTr/data/EVAL_GT'
os.makedirs(output_dir, exist_ok=True)

# 모든 CSV 파일 처리
for filename in os.listdir(input_dir):
    if filename.endswith('.csv'):
        input_path = os.path.join(input_dir, filename)
        df = pd.read_csv(input_path, header=None)  # header 없음
        
        # 4번째 컬럼이 0인 행만 필터링
        df_filtered = df[df[4] == 0].values
        print(df_filtered.shape)
        df_filtered = pd.DataFrame(df_filtered[:,0:3])
        print(df_filtered.shape)
        
        # 출력 경로 설정
        output_path = os.path.join(output_dir, filename)
        df_filtered.to_csv(output_path, index=False, header=False)
        
        print(f"Processed: {filename} → {len(df_filtered)} rows saved")
# Out:
# (918476, 5)
# (918476, 3)
# Processed: 01_merged.csv → 918476 rows saved
# (691273, 5)
# (691273, 3)
# Processed: 02_merged.csv → 691273 rows saved
# (537502, 5)
# (537502, 3)
# Processed: 03_merged.csv → 537502 rows saved
# (297085, 5)
# (297085, 3)
# Processed: 12_merged.csv → 297085 rows saved
# (472469, 5)
# (472469, 3)
# Processed: 13_merged.csv → 472469 rows saved
# (1113211, 5)
# (1113211, 3)
# Processed: 04_merged.csv → 1113211 rows saved
# (444659, 5)
# (444659, 3)
# Processed: 05_merged.csv → 444659 rows saved
# (272101, 5)
# (272101, 3)
# Processed: 14_merged.csv → 272101 rows saved
# (209886, 5)
# (209886, 3)
# Processed: 15_merged.csv → 209886 rows saved
# (536082, 5)
# (536082, 3)
# Processed: 06_merged.csv → 536082 rows saved
# (462240, 5)
# (462240, 3)
# Processed: 07_merged.csv → 462240 rows saved
# (937111, 5)
# (937111, 3)
# Processed: 16_merged.csv → 937111 rows saved
# (440570, 5)
# (440570, 3)
# Processed: 17_merged.csv → 440570 rows saved
# (776846, 5)
# (776846, 3)
# Processed: 08_merged.csv → 776846 rows saved
# (2089422, 5)
# (2089422, 3)
# Processed: 19_merged.csv → 2089422 rows saved
# (591760, 5)
# (591760, 3)
# Processed: 09_merged.csv → 591760 rows saved
# (320757, 5)
# (320757, 3)
# Processed: 18_merged.csv → 320757 rows saved
# (374028, 5)
# (374028, 3)
# Processed: 10_merged.csv → 374028 rows saved
# (530476, 5)
# (530476, 3)
# Processed: 11_merged.csv → 530476 rows saved
# (226978, 5)
# (226978, 3)
# Processed: 20_merged.csv → 226978 rows saved
# (163484, 5)
# (163484, 3)
# Processed: 21_merged.csv → 163484 rows saved
# (322584, 5)
# (322584, 3)
# Processed: 22_merged.csv → 322584 rows saved
# (95770, 5)
# (95770, 3)
# Processed: 23_merged.csv → 95770 rows saved
# (314186, 5)
# (314186, 3)
# Processed: 24_merged.csv → 314186 rows saved
# (1054824, 5)
# (1054824, 3)
# Processed: 25_merged.csv → 1054824 rows saved
# (136315, 5)
# (136315, 3)
# Processed: 28_merged.csv → 136315 rows saved
# (332508, 5)
# (332508, 3)
# Processed: 27_merged.csv → 332508 rows saved
# (925119, 5)
# (925119, 3)
# Processed: 26_merged.csv → 925119 rows saved

# %%
import os
import json
import pandas as pd

# 경로 설정
json_path = "/esail4/heeju/REGRESSION/Point-M2AE/data/segmentation/classified_json_grouped/leafwood_data_inference.json"
base_dir = "/esail4/heeju/REGRESSION/Point-M2AE/data/"
save_dir = "/esail4/heeju/REGRESSION/Point-M2AE/data/forinference"

os.makedirs(save_dir, exist_ok=True)

# JSON 읽기
with open(json_path, "r") as f:
    file_list = json.load(f)

# 그룹핑 딕셔너리
groups = {}
for path in file_list:
    filename = os.path.basename(path)  # 예: "06180002"
    prefix = filename[:4]              # 앞 4자리 (예: "0618")
    groups.setdefault(prefix, []).append(path)

# 그룹별 처리
for prefix, paths in groups.items():
    dfs = []
    for p in paths:
        csv_path = os.path.join(base_dir, p + ".csv")  # 실제 csv 경로
        if os.path.exists(csv_path):
            try:
                df = pd.read_csv(csv_path)  # 헤더 없는 경우
                dfs.append(df)
            except Exception as e:
                print(f"Error reading {csv_path}: {e}")
        else:
            print(f"Missing file: {csv_path}")

    if dfs:
        merged = pd.concat(dfs, axis=0)  # 세로로 합치기
        out_path = os.path.join(save_dir, f"{prefix}0000.csv")
        merged.to_csv(out_path, index=False, header=False)
        print(f"Saved: {out_path}")
# Out:
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09340000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06180000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/05870000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/05530000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/05570000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21610000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16850000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16890000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/04710000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/12910000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01420000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13000000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/15050000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21630000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09030000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13620000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11760000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13180000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10800000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/12390000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/05490000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/00360000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/02010000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19600000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16200000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/17000000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/02630000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06830000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/03120000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09110000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11820000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/23880000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10890000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22010000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01620000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09000000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09480000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06630000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22160000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22360000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/15510000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/17680000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/04590000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/24000000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09660000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/02930000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01260000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06530000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/17820000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13570000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09170000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/18240000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22950000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16010000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16390000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/07460000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11380000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/18290000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/15530000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/18510000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01320000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21990000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01960000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10950000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11620000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/14380000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16270000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10810000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/03330000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01230000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/23380000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13660000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22630000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22760000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13220000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/15130000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16810000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/23760000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/03890000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/08060000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13950000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10750000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09810000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/05470000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06780000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06640000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/15990000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10380000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09750000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06940000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16900000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/07720000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/08330000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/04020000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/12730000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/18040000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22680000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21850000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/20590000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22550000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19450000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/18480000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21860000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/23620000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/04330000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/08020000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/04200000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/12650000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/08290000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09250000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19480000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/12290000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/17410000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/00390000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09920000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09320000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22410000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/12310000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/00630000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/12470000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11310000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16970000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/05950000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/00180000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/15070000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21590000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13960000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/18160000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/20670000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/05640000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/12760000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/03440000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/07400000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11440000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/08480000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19210000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21270000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19050000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22770000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/08180000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11360000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/18010000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16330000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/08850000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/20370000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13110000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/05110000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10190000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10840000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/23560000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13480000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21740000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21380000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/07810000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/00820000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/05410000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01140000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21750000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/07670000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/18370000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/15100000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13980000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/12780000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16630000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19810000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01800000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19000000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/15710000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/07410000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/17270000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/04070000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06750000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11300000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/14360000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/02640000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10030000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/17380000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11490000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/04140000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21390000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06620000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13750000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09710000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/14600000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/03610000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10770000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09210000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/14740000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13290000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/05240000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/02680000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21480000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22700000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10590000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/12870000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09720000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16420000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19740000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/08780000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/14760000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13210000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/00890000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09670000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01770000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10170000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06400000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11630000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/15320000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/04440000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01510000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06520000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09180000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/14490000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13790000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/17530000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19350000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/10600000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/17770000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01080000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/08350000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19180000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/14210000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/09490000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/08620000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11510000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/21970000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/15430000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/13340000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/11660000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/03060000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/02920000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/06800000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/17670000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16570000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/01600000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22030000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/22810000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/16760000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/19610000.csv
# Saved: /esail4/heeju/REGRESSION/Point-M2AE/data/forinference/17180000.csv

# %%
import os
import re
import json
import shutil
from pathlib import Path
from collections import defaultdict

# 경로 설정
base_dir = Path("/esail4/heeju/REGRESSION/Point-M2AE/data")
json_path = base_dir / "segmentation" / "classified_json_grouped" / "leafwood_data_inference.json"
forinf_dir = base_dir / "forinference"

# 안전장치: 경로 존재 확인
if not json_path.exists():
    raise FileNotFoundError(f"JSON이 없습니다: {json_path}")
if not forinf_dir.exists():
    raise FileNotFoundError(f"forinference 폴더가 없습니다: {forinf_dir}")

# 1) JSON 읽어서 prefix -> {groups} 매핑 만들기
with open(json_path, "r") as f:
    items = json.load(f)

prefix_to_groups = defaultdict(set)
pat = re.compile(r"^segmentation/([^/]+)/(\d{8})$")  # segmentation/<group>/<8digits>

for it in items:
    m = pat.match(it.strip())
    if not m:
        # 예상 포맷이 아니면 스킵
        continue
    group, eight = m.groups()
    prefix = eight[:4]  # 앞 4자리
    prefix_to_groups[prefix].add(group)

# 2) forinference 내의 8자리 csv 파일들을 분배
csv_pat = re.compile(r"^(\d{8})\.csv$")
moved, copied, skipped, not_found_prefix = 0, 0, 0, 0

for entry in sorted(forinf_dir.iterdir()):
    if not entry.is_file():
        continue
    m = csv_pat.match(entry.name)
    if not m:
        # 8자리.csv 형태가 아니면 무시
        continue

    eight = m.group(1)         # 예: 06180000
    prefix = eight[:4]          # 예: 0618
    groups = sorted(prefix_to_groups.get(prefix, []))

    if not groups:
        print(f"[WARN] 매칭되는 그룹이 없어 스킵: {entry.name} (prefix={prefix})")
        not_found_prefix += 1
        continue

    # 그룹 폴더들 생성
    group_dirs = [forinf_dir / g for g in groups]
    for gd in group_dirs:
        gd.mkdir(parents=True, exist_ok=True)

    # 첫 번째 그룹으로 이동
    first_dst = group_dirs[0] / entry.name
    try:
        # 이미 목적지에 파일이 있으면 덮어쓰기
        if first_dst.exists():
            first_dst.unlink()
        shutil.move(str(entry), str(first_dst))
        moved += 1
        print(f"[MOVE] {entry.name} → {groups[0]}/{entry.name}")
    except Exception as e:
        print(f"[ERROR] 이동 실패: {entry.name} → {groups[0]} :: {e}")
        skipped += 1
        continue

    # 나머지 그룹에는 복사
    for gdir in group_dirs[1:]:
        dst = gdir / first_dst.name
        try:
            # 이미 있으면 건너뜀(원하시면 덮어쓰기로 바꿀 수 있음)
            if dst.exists():
                print(f"[SKIP] 이미 존재: {gdir.name}/{dst.name}")
                continue
            shutil.copy2(str(first_dst), str(dst))
            copied += 1
            print(f"[COPY] {first_dst.name} → {gdir.name}/{dst.name}")
        except Exception as e:
# [MOVE] 22360000.csv → 33333333/22360000.csv
# [MOVE] 22410000.csv → 33333333/22410000.csv
# [MOVE] 22550000.csv → 33333333/22550000.csv
# [MOVE] 22630000.csv → 33333333/22630000.csv
# [MOVE] 22680000.csv → 33333333/22680000.csv
# [MOVE] 22700000.csv → 33333333/22700000.csv
# [MOVE] 22760000.csv → 33333333/22760000.csv
# [MOVE] 22770000.csv → 33333333/22770000.csv
# [MOVE] 22810000.csv → 33333333/22810000.csv
# [MOVE] 22950000.csv → 22222222/22950000.csv
# [MOVE] 23380000.csv → 33333333/23380000.csv
# [MOVE] 23560000.csv → 33333333/23560000.csv
# [MOVE] 23620000.csv → 33333333/23620000.csv
# [MOVE] 23760000.csv → 33333333/23760000.csv
# [MOVE] 23880000.csv → 22222222/23880000.csv
# [MOVE] 24000000.csv → 22222222/24000000.csv
#
# === 요약 ===
# 이동(MOVE): 240
# 복사(COPY): 0
# 스킵/오류(SKIP): 0
# 매칭 없는 prefix 파일: 0

# %%
import os
import glob
import pandas as pd
import torch
import numpy as np
import random

# ----- 다운샘플 함수: 선택 인덱스도 함께 반환 -----
def point_cloud_down_with_indices(xyz, ratio, center_sigma):
    """
    xyz: torch.Tensor (N,3) or (1,N,3)
    return: (1,M,3), sampled_idx(LongTensor shape [M])
    """
    random.seed(42)
    torch.manual_seed(42)

    if xyz.dim() == 3:
        xyz = xyz.squeeze(0)  # (N,3)

    N = xyz.shape[0]
    target_N = max(1, int(N * ratio))

    center = xyz[torch.randint(0, N, (1,)).item()]
    dists = torch.linalg.norm(xyz - center, dim=1)
    # 수치 안정성을 위해 softmax 사용 (exp/합 대신)
    prob = torch.softmax(dists / center_sigma, dim=0)
    sampled_idx = torch.multinomial(prob, target_N, replacement=False)

    crop_data = xyz[sampled_idx].unsqueeze(0).contiguous()  # (1,M,3)
    return crop_data, sampled_idx

# ----- 경로/하이퍼파라미터 -----
ROOT = "/esail4/heeju/REGRESSION/Point-M2AE/data"
FORINF = os.path.join(ROOT, "forinference")
OUTROOT = os.path.join(ROOT, "09masked")

RATIO = 0.6       # 남길 비율
CENTER_SIGMA = 0.5  # 거리 가중치 스케일

GROUPS = ["22222222", "33333333"]
os.makedirs(OUTROOT, exist_ok=True)

def process_group(group_name: str):
    src_dir = os.path.join(FORINF, group_name)
    dst_dir = os.path.join(OUTROOT, group_name)
    os.makedirs(dst_dir, exist_ok=True)

    csv_list = sorted(glob.glob(os.path.join(src_dir, "*.csv")))
    if not csv_list:
        print(f"[INFO] No CSVs in {src_dir}")
        return

    for csv_path in csv_list:
        try:
            # 헤더 없음: 구분자 자동 감지
            df = pd.read_csv(csv_path, header=None, sep=None, engine="python")

            if df.shape[1] < 3:
                print(f"[SKIP] {csv_path}: 열이 3개 미만입니다({df.shape[1]}개).")
                continue

            # (x,y,z,type) 정규화
            if df.shape[1] >= 4:
                df = df.iloc[:, :4]
                df.columns = ['x','y','z','type']
            else:
                df.columns = ['x','y','z']
                df['type'] = -1

            # 타입/좌표 형 변환
            xyz_np = df[['x','y','z']].to_numpy(dtype=np.float32)
            try:
                type_np = df['type'].to_numpy(dtype=np.int32)
            except Exception:
                type_np = df['type'].to_numpy()
            
            # Torch 텐서 변환
            pts = torch.from_numpy(xyz_np)

            # 다운샘플 + 인덱스 획득
            down, sampled_idx = point_cloud_down_with_indices(
                pts, ratio=RATIO, center_sigma=CENTER_SIGMA
            )
            down_np = down.squeeze(0).cpu().numpy()
            sel_idx = sampled_idx.cpu().numpy()
            sel_type = type_np[sel_idx].reshape(-1, 1)

            # x,y,z,type 붙여 저장
            out_arr = np.hstack([down_np, sel_type])
            out_df = pd.DataFrame(out_arr)

            fname = os.path.basename(csv_path)  # 예: 06180000.csv
            out_path = os.path.join(dst_dir, fname)
            out_df.to_csv(out_path, index=False, header=False)
            print(f"[OK] {group_name} :: {fname} → {out_path} (N={len(df)}, M={out_arr.shape[0]})")

        except Exception as e:
            print(f"[ERROR] {csv_path}: {e}")

for g in GROUPS:
    process_group(g)
# Out:
# [OK] 22222222 :: 06620000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/06620000.csv (N=1800816, M=1080489)
# [OK] 22222222 :: 06630000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/06630000.csv (N=6256194, M=3753716)
# [OK] 22222222 :: 06640000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/06640000.csv (N=3564413, M=2138647)
# [OK] 22222222 :: 07670000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/07670000.csv (N=763341, M=458004)
# [OK] 22222222 :: 08620000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/08620000.csv (N=493387, M=296032)
# [OK] 22222222 :: 15320000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/15320000.csv (N=568711, M=341226)
# [OK] 22222222 :: 16270000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/16270000.csv (N=2377039, M=1426223)
# [OK] 22222222 :: 17270000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/17270000.csv (N=2215852, M=1329511)
# [OK] 22222222 :: 18240000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/18240000.csv (N=1435207, M=861124)
# [OK] 22222222 :: 19180000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/19180000.csv (N=1635596, M=981357)
# [OK] 22222222 :: 21970000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/21970000.csv (N=328867, M=197320)
# [OK] 22222222 :: 21990000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/21990000.csv (N=671438, M=402862)
# [OK] 22222222 :: 22010000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/22010000.csv (N=1142520, M=685512)
# [OK] 22222222 :: 22030000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/22030000.csv (N=521236, M=312741)
# [OK] 22222222 :: 22950000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/22950000.csv (N=531204, M=318722)
# [OK] 22222222 :: 23880000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/23880000.csv (N=426156, M=255693)
# [OK] 22222222 :: 24000000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/22222222/24000000.csv (N=692232, M=415339)
# [OK] 33333333 :: 00180000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333/00180000.csv (N=176618, M=105970)
# [OK] 33333333 :: 00360000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333/00360000.csv (N=786593, M=471955)
# [OK] 33333333 :: 00390000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333/00390000.csv (N=391430, M=234858)
# [OK] 33333333 :: 00630000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333/00630000.csv (N=2708796, M=1625277)
# [OK] 33333333 :: 00820000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333/00820000.csv (N=394085, M=236451)
# [OK] 33333333 :: 00890000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333/00890000.csv (N=448148, M=268888)
# [OK] 33333333 :: 01080000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333/01080000.csv (N=612863, M=367717)
# [OK] 33333333 :: 01140000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333/01140000.csv (N=108817, M=65290)
# [OK] 33333333 :: 01230000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333/01230000.csv (N=184005, M=110403)
# [OK] 33333333 :: 01260000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333/01260000.csv (N=268206, M=160923)
# [OK] 33333333 :: 01320000.csv → /esail4/heeju/REGRESSION/Point-M2AE/data/09masked/33333333